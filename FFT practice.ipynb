# %%
import numpy as np
from scipy.fftpack import fft, ifft
x = np.array([1.0, 2.0, 1.0, -1.0, 1.5])
y = fft(x)
y
# Out:
# array([ 4.50000000+0.j        ,  2.08155948-1.65109876j,
#        -1.83155948+1.60822041j, -1.83155948-1.60822041j,
#         2.08155948+1.65109876j])

# %%
yinv = ifft(y)
yinv
# Out:
# array([ 1.0+0.j,  2.0+0.j,  1.0+0.j, -1.0+0.j,  1.5+0.j])

# %%
import numpy as np
from scipy.fftpack import fft
N = 600
T = 1.0 / 800.0
x = np.linspace(0.0, N*T, N)
y = np.sin(50.0 * 2.0*np.pi*x) + 0.5*np.sin(80.0 * 2.0*np.pi*x)
yf = fft(y)
xf = np.linspace(0.0, 1.0/(2.0*T), N/2)
import matplotlib.pyplot as plt
plt.plot(xf, 2.0/N * np.abs(yf[0:N/2]))
plt.grid()
plt.show()
# Out:
# //anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
plt.plot(x,y)

# %%
import numpy as np
from scipy.fftpack import fft
N = 600
T = 1.0 / 800.0
x = np.linspace(0.0, N*T, N)

# %%
import matplotlib.pyplot as plt
plt.plot(x,y)
# Out:
# //anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
plt.show()

# %%
import numpy as np
import pandas as pd
df1 = pd.read_csv('allquakes.csv', dtype=object)
df1
# Out:
#        cluster   depth  Latitude  Longitude  mag startday startmonth  \
# 0            5     0.0     57.09    -153.48  8.3       10         10
# 1            5     0.0      60.0     -135.0  7.1       18          1
# 2            5     0.0      52.0     -160.0  6.6       30         12
# 3            5     0.0     51.45    -171.02  7.8       31         12
# 4            5     0.0     52.38    -167.45  7.8        1          1
# 5            5     0.0     50.85    -175.16  7.0       17          1
# 6            5     0.0      52.0      175.0  6.8        5          2
# 7            5     0.0     61.56    -158.54  8.3        2          6
# 8            5     0.0     64.62    -148.23  7.8       27          8
# 9            5     0.0     50.73    -178.55  7.7       14          2
# 10           5     0.0     51.28     174.83  7.2       22          3
# 11           7     0.0     52.06     171.45  7.4       15          9
# 12           5     0.0     53.88    -161.68  7.0       10         12
# ...

# %%
df1['mag'] = pd.to_numeric(df1['mag'])
df2 = df1['startyear'][(df1['cluster'] == '14') &(df1['mag'] >= 5)].value_counts()
#

# %%
df2 = pd.DataFrame(df2)
df2
# Out:
#       startyear
# 1976        116
# 2007        116
# 1983        110
# 2010        109
# 2014        106
# 2005        105
# 1979        104
# 2009        101
# 1974        100
# 1988         99
# 1992         99
# 1990         96
# 1982         95
# 1991         91
# 2012         90
# 2008         90
# 2015         86
# 2006         85
# 1985         84
# 1995         82
# 2004         81
# 1997         80
# 1970         79
# 1978         79
# 1984         77
# 1969         77
# 2001         76
# 2011         75
# 1965         75
# 1977         72
# 1981         72
# 1968         71
# 1973         71
# 2002         70
# 2000         69
# 1989         68
# 1980         68
# 1996         66
# 1986         63
# 1987         63
# 1999         62
# 1998         61
# 1975         60
# 1994         59
# 2016         56
# 1971         56
# 1972         54
# 2013         52
# 1966         51
# 2003         50
# 1967         50
# 1993         49
# 1964         48
# 1963         39
# ...

# %%
df2['count'] = df2['startyear']
del df2['startyear']
df2.to_csv('count.csv')

# %%
import numpy as np
import pandas as pd
from scipy.fftpack import fft, ifft
df = pd.read_csv('count.csv', dtype=object)

# %%
df = df.sort(['year'])
df.index = range(len(df))
df['year'] = pd.to_numeric(df['year'])
df['count'] = pd.to_numeric(df['count'])
df = df[(df['year'] >= 1963) & (df['year'] <= 2015)]
#
x = df['year'].values
y = df['count'].values
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':

# %%
#df = df.append({'year':1984, 'count':0}, ignore_index=True)

# %%
import scipy.fftpack
yf = scipy.fftpack.fft(y)

# %%
yf
# Out:
# array([  4.10700000e+03  +0.j        ,  -6.28756245e+01 +24.59824353j,
#         -9.74347463e+01+315.46898501j,  -1.69650495e+02+142.07542797j,
#         -5.15371647e+01 -65.93984598j,  -3.03656632e+01 -20.28761149j,
#          5.19189798e+01 -22.4691426j ,  -8.42524398e+01+186.94359159j,
#          1.11365962e+02 +40.31099278j,  -4.20239026e+01 +29.66392468j,
#          6.00289681e+01 -16.24518032j,   1.96928342e+00 +38.78138057j,
#         -2.51102465e+02 +41.41405265j,  -4.01391697e+01 +39.04414328j,
#         -1.17219328e+02 +22.03776389j,  -5.58943919e+01 +89.15663257j,
#         -9.02070827e+01 +87.01938603j,   1.21899715e+00-141.9297951j ,
#         -1.55793258e+02 +61.76076886j,  -1.79143553e+01+147.76279071j,
#         -7.48845645e+00 +40.71307114j,  -1.15146923e+02 -54.10348482j,
#         -7.82171617e+01-183.59756151j,   1.99656431e+01 +99.20669802j,
#          1.45183731e+02-103.73726814j,   6.79360253e+01 -27.16318434j,
# ...

# %%
len(yf)
# Out:
# 53

# %%
xf = np.linspace(0.0, 0.5, 53/2)

# %%
import matplotlib.pyplot as plt
plt.plot(xf, 2.0/53 * np.abs(yf[0:53/2]))

# %%
plt.grid()
plt.show()
