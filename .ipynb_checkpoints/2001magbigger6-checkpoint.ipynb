# %%
import numpy as np
import pandas as pd
file = open('catsearchwcluster.csv', 'r')
mags = []
datetimes = []
years = []
months = []
days = []
clus = []
types = []

firstline = True
for line in file:
    if firstline:    #skip first line
        firstline = False
        continue
    data = line.strip().split(',')
    datetime = str(data[0])
    datetimes.append(datetime)
    year = str(data[0])[:4]
    years.append(year)
    month = str(data[0])[5:7]
    months.append(month)
    day = str(data[0])[8:10]
    days.append(day)
    mag = float(data[4])
    mags.append(mag)
    clu = int(data[-1])
    clus.append(clu)
    typ = str('E')
    types.append(typ)
    
mags = np.asarray(mags)
datetimes = np.asarray(datetimes)
years = np.asarray(years)
months = np.asarray(months)
days = np.asarray(days)
clus = np.asarray(clus)
types = np.asarray(types)

# %%
all_data = {'startyear': years, 'startmonth': months, 'startday': days, 'mag': mags, 'cluster': clus, 'type': types}

# %%
df = pd.DataFrame(all_data)
df
# Out:
#         cluster  mag startday startmonth startyear type
# 0            12  7.6       29         06      1898    E
# 1            12  6.9       11         10      1898    E
# 2             4  7.2       14         07      1899    E
# 3             4  8.3       04         09      1899    E
# 4             4  6.9       04         09      1899    E
# 5             4  7.8       10         09      1899    E
# 6             4  8.6       10         09      1899    E
# 7             4  6.9       17         09      1899    E
# 8             4  6.9       23         09      1899    E
# 9             4  7.0       23         09      1899    E
# 10            4  6.8       29         09      1899    E
# 11            4  8.3       10         10      1900    E
# 12            4  7.1       18         01      1901    E
# 13            4  6.6       30         12      1901    E
# 14           12  7.8       31         12      1901    E
# 15           12  7.8       01         01      1902    E
# 16           12  7.0       17         01      1903    E
# 17           12  6.8       05         02      1903    E
# 18            4  8.3       02         06      1903    E
# 19            4  7.8       27         08      1904    E
# 20           12  7.7       14         02      1905    E
# 21           12  7.2       22         03      1905    E
# 22           12  7.4       15         09      1905    E
# 23           12  7.0       10         12      1905    E
# 24           12  8.0       17         08      1906    E
# 25           12  7.6       23         12      1906    E
# 26            4  6.5       22         08      1907    E
# 27           12  7.7       02         09      1907    E
# 28            4  7.1       15         05      1908    E
# 29           12  7.0       10         04      1909    E
# ...         ...  ...      ...        ...       ...  ...
# 617840       10  4.6       04         07      2016    E
# 617841       10  4.9       04         07      2016    E
# 617842        5  4.2       04         07      2016    E
# 617843       12  4.6       04         07      2016    E
# 617844        5  4.4       04         07      2016    E
# 617845        3  4.7       04         07      2016    E
# 617846        2  4.3       04         07      2016    E
# 617847       12  4.4       04         07      2016    E
# 617848        3  5.0       05         07      2016    E
# 617849        2  3.0       05         07      2016    E
# 617850        5  4.4       05         07      2016    E
# 617851        5  4.5       05         07      2016    E
# 617852       12  4.8       05         07      2016    E
# 617853        5  4.4       05         07      2016    E
# 617854        4  3.1       05         07      2016    E
# 617855       12  5.2       05         07      2016    E
# 617856        5  4.3       05         07      2016    E
# 617857        2  3.5       05         07      2016    E
# 617858        3  4.3       05         07      2016    E
# 617859       10  5.2       05         07      2016    E
# 617860        5  4.3       05         07      2016    E
# 617861        2  3.5       05         07      2016    E
# 617862        5  4.4       05         07      2016    E
# 617863       12  4.6       05         07      2016    E
# 617864        4  4.3       05         07      2016    E
# 617865       12  4.4       05         07      2016    E
# 617866       10  4.8       06         07      2016    E
# 617867       10  5.9       06         07      2016    E
# 617868       12  3.8       06         07      2016    E
# 617869       11  4.3       06         07      2016    E
#
# [617870 rows x 6 columns]

# %%
df2 = df.query('startyear == "2001" and mag >= 6')

# %%
df2
# Out:
#         cluster   mag startday startmonth startyear type
# 325668        5  7.50       01         01      2001    E
# 325672        5  6.80       01         01      2001    E
# 325705        5  6.40       02         01      2001    E
# 325724       10  6.00       02         01      2001    E
# 325955       10  7.10       09         01      2001    E
# 326005        4  6.93       10         01      2001    E
# 326023        4  6.00       11         01      2001    E
# 326096        2  7.70       13         01      2001    E
# 326177        7  6.40       15         01      2001    E
# 326229        5  6.00       16         01      2001    E
# 326230        5  6.90       16         01      2001    E
# 326340        2  6.00       19         01      2001    E
# 326349       10  6.30       19         01      2001    E
# 326352        6  6.00       19         01      2001    E
# 326640        5  7.70       26         01      2001    E
# 326795        5  6.20       29         01      2001    E
# 326926       12  6.00       01         02      2001    E
# 327425        2  6.60       13         02      2001    E
# 327441        5  7.40       13         02      2001    E
# 327476       10  6.10       14         02      2001    E
# 327478       10  6.20       14         02      2001    E
# 327526        5  6.10       16         02      2001    E
# 327596        4  6.20       17         02      2001    E
# 327641        7  6.00       18         02      2001    E
# 327862        5  7.10       24         02      2001    E
# 327875        5  6.20       24         02      2001    E
# 327907        5  6.20       25         02      2001    E
# 327972       12  6.10       26         02      2001    E
# 328081       10  6.70       28         02      2001    E
# 328083       10  6.30       28         02      2001    E
# ...         ...   ...      ...        ...       ...  ...
# 337982        2  6.00       17         10      2001    E
# 338061        5  7.50       19         10      2001    E
# 338141       10  6.70       21         10      2001    E
# 338406       10  6.10       26         10      2001    E
# 338605       10  7.00       31         10      2001    E
# 338855       10  6.30       05         11      2001    E
# 338995        2  6.10       09         11      2001    E
# 339204        2  6.10       13         11      2001    E
# 339209       12  6.00       13         11      2001    E
# 339210       12  6.00       13         11      2001    E
# 339260        5  7.80       14         11      2001    E
# 339302       11  6.30       15         11      2001    E
# 339543        5  6.20       20         11      2001    E
# 339609       10  6.30       22         11      2001    E
# 339610       10  6.20       22         11      2001    E
# 339650        5  6.10       23         11      2001    E
# 339782       10  6.00       27         11      2001    E
# 339853        2  6.40       28         11      2001    E
# 340038       10  6.00       02         12      2001    E
# 340056       12  6.50       02         12      2001    E
# 340094       10  6.40       03         12      2001    E
# 340368        5  6.20       08         12      2001    E
# 340430        5  6.10       09         12      2001    E
# 340533       10  6.10       12         12      2001    E
# 340535       10  7.10       12         12      2001    E
# 340777        5  6.80       18         12      2001    E
# 340961       10  6.00       22         12      2001    E
# 341034       10  6.80       23         12      2001    E
# 341190       10  6.20       27         12      2001    E
# 341252       11  6.00       28         12      2001    E
#
# [138 rows x 6 columns]

# %%
df2.to_csv('2001magbigger6.csv')
