# %%
import numpy as np
from scipy.fftpack import fft, ifft
x = np.array([1.0, 2.0, 1.0, -1.0, 1.5])
y = fft(x)
y
# Out:
# array([ 4.50000000+0.j        ,  2.08155948-1.65109876j,
#        -1.83155948+1.60822041j, -1.83155948-1.60822041j,
#         2.08155948+1.65109876j])

# %%
yinv = ifft(y)
yinv
# Out:
# array([ 1.0+0.j,  2.0+0.j,  1.0+0.j, -1.0+0.j,  1.5+0.j])

# %%
import numpy as np
from scipy.fftpack import fft
N = 600
T = 1.0 / 800.0
x = np.linspace(0.0, N*T, N)
y = np.sin(50.0 * 2.0*np.pi*x) + 0.5*np.sin(80.0 * 2.0*np.pi*x)
yf = fft(y)
xf = np.linspace(0.0, 1.0/(2.0*T), N/2)
import matplotlib.pyplot as plt
plt.plot(xf, 2.0/N * np.abs(yf[0:N/2]))
plt.grid()
plt.show()
# Out:
# //anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
plt.plot(x,y)

# %%
import numpy as np
from scipy.fftpack import fft
N = 600
T = 1.0 / 800.0
x = np.linspace(0.0, N*T, N)

# %%
import matplotlib.pyplot as plt
plt.plot(x,y)
# Out:
# //anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
plt.show()

# %%
import numpy as np
import pandas as pd
df1 = pd.read_csv('allquakes.csv', dtype=object)
df1
# Out:
#        cluster   depth  Latitude  Longitude  mag startday startmonth  \
# 0            5     0.0     57.09    -153.48  8.3       10         10
# 1            5     0.0      60.0     -135.0  7.1       18          1
# 2            5     0.0      52.0     -160.0  6.6       30         12
# 3            5     0.0     51.45    -171.02  7.8       31         12
# 4            5     0.0     52.38    -167.45  7.8        1          1
# 5            5     0.0     50.85    -175.16  7.0       17          1
# 6            5     0.0      52.0      175.0  6.8        5          2
# 7            5     0.0     61.56    -158.54  8.3        2          6
# 8            5     0.0     64.62    -148.23  7.8       27          8
# 9            5     0.0     50.73    -178.55  7.7       14          2
# 10           5     0.0     51.28     174.83  7.2       22          3
# 11           7     0.0     52.06     171.45  7.4       15          9
# 12           5     0.0     53.88    -161.68  7.0       10         12
# 13           5     0.0     50.77     179.73  8.0       17          8
# 14           5     0.0      53.0     -165.0  7.6       23         12
# 15           5   120.0      57.0     -161.0  6.5       22          8
# 16           7     0.0     52.44     170.28  7.7        2          9
# 17           5    25.0      59.0     -141.0  7.1       15          5
# 18           5     0.0      52.0      175.0  7.0       10          4
# 19           5    90.0      52.5     -169.0  7.4        8          9
# 20           5     0.0      60.0     -149.5  7.4       19          9
# 21           5   100.0      57.0     -160.0  6.7       13          5
# 22           0     NaN      42.0     -127.0  6.8        5          8
# 23           5    25.0     50.75     179.38  7.3        9          9
# 24           5     0.0      53.0     -135.0  6.8        6         11
# 25           0     NaN     37.25    -121.75  6.6        1          7
# 26           5     0.0      51.0      180.0  7.1       17          9
# 27           5    60.0      60.5     -149.0  6.9       22          9
# 28           7     0.0      52.0      173.0  7.0       13         11
# 29           5    25.0      52.0     -179.0  7.1        4          1
# ...        ...     ...       ...        ...  ...      ...        ...
# 617829      11  591.48   -21.541  -179.1091  4.6        4          7
# 617830      11    6.56  -21.3093   168.6738  4.9        4          7
# 617831      13    10.0   39.5984     73.068  4.2        4          7
# 617832       7     9.1   29.6131   143.3523  4.6        4          7
# 617833       6   43.29   -2.1018    138.966  4.4        4          7
# 617834       3   93.55  -20.6978   -69.1784  4.7        4          7
# 617835       0   31.94   16.6123   -97.8297  4.3        4          7
# 617836       7    35.0   46.8062   152.8785  4.4        4          7
# 617837       3    11.2  -20.1948   -70.9115  5.0        5          7
# 617838       0    9.11   36.1518   -89.6965  3.0        5          7
# 617839       8   98.55   24.8082    95.2124  4.4        5          7
# 617840       6    35.0   -0.2665   125.5466  4.5        5          7
# 617841       7    10.0   35.5119   129.8661  4.8        5          7
# 617842       6    35.0   -0.3386   125.4749  4.4        5          7
# 617843       5    10.0   43.3325  -126.6572  3.1        5          7
# 617844       1   36.21   21.8613   145.3276  5.2        5          7
# 617845      13   155.4   38.2305    73.6797  4.3        5          7
# 617846       0     5.0   36.2626   -97.5821  3.5        5          7
# 617847       3   39.51  -41.6855   -74.0542  4.3        5          7
# 617848      11    10.0   -32.927  -177.8664  5.2        5          7
# 617849       6  192.36    2.0851   128.3228  4.3        5          7
# 617850       0     5.0   37.3679   -98.2025  3.5        5          7
# 617851      13    10.0    39.489    73.4459  4.4        5          7
# 617852       7   29.15   29.7514   142.1428  4.6        5          7
# 617853       5    10.0   44.1651  -128.9059  4.3        5          7
# 617854       7   21.26   35.7802   140.9868  4.4        5          7
# 617855      11  257.05  -18.8947   169.4241  4.8        6          7
# 617856       4    10.0  -56.8016  -142.1336  5.9        6          7
# 617857       5    10.0   53.4488  -163.4493  3.8        6          7
# 617858      14    35.0     0.166   -79.8907  4.3        6          7
#
#        startyear type
# 0           1900    1
# 1           1901    1
# 2           1901    1
# 3           1901    1
# 4           1902    1
# 5           1903    1
# 6           1903    1
# 7           1903    1
# 8           1904    1
# 9           1905    1
# 10          1905    1
# 11          1905    1
# 12          1905    1
# 13          1906    1
# 14          1906    1
# 15          1907    1
# 16          1907    1
# 17          1908    1
# 18          1909    1
# 19          1909    1
# 20          1909    1
# 21          1910    1
# 22          1910    1
# 23          1910    1
# 24          1910    1
# 25          1911    1
# 26          1911    1
# 27          1911    1
# 28          1911    1
# 29          1912    1
# ...          ...  ...
# 617829      2016    1
# 617830      2016    1
# 617831      2016    1
# 617832      2016    1
# 617833      2016    1
# 617834      2016    1
# 617835      2016    1
# 617836      2016    1
# 617837      2016    1
# 617838      2016    1
# 617839      2016    1
# 617840      2016    1
# 617841      2016    1
# 617842      2016    1
# 617843      2016    1
# 617844      2016    1
# 617845      2016    1
# 617846      2016    1
# 617847      2016    1
# 617848      2016    1
# 617849      2016    1
# 617850      2016    1
# 617851      2016    1
# 617852      2016    1
# 617853      2016    1
# 617854      2016    1
# 617855      2016    1
# 617856      2016    1
# 617857      2016    1
# 617858      2016    1
#
# [617859 rows x 9 columns]

# %%
df1['mag'] = pd.to_numeric(df1['mag'])
df2 = df1['startyear'][(df1['cluster'] == '7') &(df1['mag'] >= 5)].value_counts()
#

# %%
df2 = pd.DataFrame(df2)
df2
# Out:
#       startyear
# 2011        869
# 1994        312
# 1978        276
# 1965        262
# 1995        245
# 1983        224
# 1975        224
# 2006        211
# 1968        199
# 1976        198
# 1973        197
# 2013        191
# 2012        189
# 1992        181
# 2000        174
# 1969        173
# 1984        170
# 2003        166
# 1997        163
# 1996        161
# 1989        159
# 1991        156
# 1993        153
# 1963        150
# 1982        149
# 2007        148
# 2004        140
# 1964        140
# 1987        139
# 1971        138
# ...         ...
# 1970        123
# 1972        123
# 1999        122
# 1985        121
# 1977        117
# 2005        116
# 1990        112
# 2001        110
# 1986        108
# 1966        104
# 1967         99
# 2009         98
# 2010         96
# 2015         95
# 2014         95
# 1979         92
# 2002         90
# 1998         83
# 2016         42
# 1940          2
# 1961          2
# 1962          2
# 1956          1
# 1953          1
# 1931          1
# 1911          1
# 1905          1
# 1907          1
# 1929          1
# 1950          1
#
# [65 rows x 1 columns]

# %%
df2['count'] = df2['startyear']
del df2['startyear']
df2.to_csv('count.csv')

# %%
import numpy as np
import pandas as pd
from scipy.fftpack import fft, ifft
df = pd.read_csv('count.csv', dtype=object)

# %%
df = df.sort(['year'])
df.index = range(len(df))
df['year'] = pd.to_numeric(df['year'])
df['count'] = pd.to_numeric(df['count'])
df = df[(df['year'] >= 1963) & (df['year'] <= 2015)]
#
x = df['year'].values
y = df['count'].values
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':

# %%
#df = df.append({'year':1984, 'count':0}, ignore_index=True)

# %%
import scipy.fftpack
yf = scipy.fftpack.fft(y)

# %%
yf
# Out:
# array([  8.80500000e+03   +0.j        ,   3.97172366e+02 +215.08276811j,
#          2.85714547e+02 +367.50883751j,  -1.12667203e+02+1137.64585421j,
#         -5.99460109e+02 +119.58475355j,  -2.39283618e+02 +156.12059832j,
#         -1.13978708e+03 -315.3401865j ,  -4.95054842e+02 -562.70490761j,
#         -2.78279399e+00 -654.57682391j,   9.30399209e+01-1215.39974004j,
#          9.79443815e+02 -365.5563978j ,   7.29092768e+02 -286.53740787j,
#          3.93661509e+02 +144.51394741j,   1.92726882e+02 +763.81989216j,
#         -5.20566876e+02 +522.83473924j,  -8.40670574e+02 +341.79094854j,
#         -8.59632982e+02   -6.85168915j,  -2.86347453e+02  -17.86774439j,
#         -3.23322301e+02 -354.89008482j,  -1.93179976e+01 -979.1694916j ,
#          6.38120639e+02  +99.60151055j,   1.10057580e+03  +67.73501134j,
#          1.03078085e+03 +251.24075149j,   4.09779224e+00 +695.81434646j,
#          7.24136435e+00 +964.92449816j,  -2.75242511e+02 +556.44279931j,
#         -5.65031917e+02 +149.87368807j,  -5.65031917e+02 -149.87368807j,
#         -2.75242511e+02 -556.44279931j,   7.24136435e+00 -964.92449816j,
#          4.09779224e+00 -695.81434646j,   1.03078085e+03 -251.24075149j,
#          1.10057580e+03  -67.73501134j,   6.38120639e+02  -99.60151055j,
#         -1.93179976e+01 +979.1694916j ,  -3.23322301e+02 +354.89008482j,
#         -2.86347453e+02  +17.86774439j,  -8.59632982e+02   +6.85168915j,
#         -8.40670574e+02 -341.79094854j,  -5.20566876e+02 -522.83473924j,
#          1.92726882e+02 -763.81989216j,   3.93661509e+02 -144.51394741j,
#          7.29092768e+02 +286.53740787j,   9.79443815e+02 +365.5563978j ,
#          9.30399209e+01+1215.39974004j,  -2.78279399e+00 +654.57682391j,
#         -4.95054842e+02 +562.70490761j,  -1.13978708e+03 +315.3401865j ,
#         -2.39283618e+02 -156.12059832j,  -5.99460109e+02 -119.58475355j,
#         -1.12667203e+02-1137.64585421j,   2.85714547e+02 -367.50883751j,
#          3.97172366e+02 -215.08276811j])

# %%
len(yf)
# Out:
# 53

# %%
xf = np.linspace(0.0, 0.5, 53/2)

# %%
import matplotlib.pyplot as plt
plt.plot(xf, 2.0/53 * np.abs(yf[0:53/2]))
# Out:
# //anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
plt.grid()
plt.show()
