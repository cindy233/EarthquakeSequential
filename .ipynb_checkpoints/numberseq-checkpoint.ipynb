# %%
import numpy as np
import pandas as pd
df1 = pd.read_csv('allvolcanoes.csv', dtype=object)
df1['startdate'] = df1.apply(lambda row: '{0}/{1}/{2}'.format(row['Start_Month'],row['Start_Day'],row['Start_Year']), axis=1)
#print(df1['startdate'])
df1['startdate'] = pd.to_datetime(df1.startdate)
df1 = df1.sort_values(by = ['startdate'])
df1['type'] = '0'
df1
# Out:
#      Volcano_Number            Volcano_Name Eruption_Number  \
# 0            241050                Okataina           14508
# 1            283110               Asamayama           17762
# 2            273030                   Mayon           16795
# 3            263300                  Semeru           13571
# 4            233020  Fournaise  Piton de la           14306
# 5            315020                Wrangell           20412
# 6            261230                   Dempo           15558
# 7            283170             Adatarayama           17912
# 8            283120      Kusatsu-Shiranesan           17826
# 9            261230                   Dempo           15559
# 10           264030                 Rinjani           16213
# 11           263300                  Semeru           13572
# 12           266030                 Soputan           13584
# 13           233020  Fournaise  Piton de la           14307
# 14           357010             Tupungatito           11894
# ...

# %%
df = pd.read_csv('allquakes.csv', dtype=object)
df['startdate'] = df.apply(lambda row: '{0}/{1}/{2}'.format(row['startyear'],row['startmonth'],row['startday']), axis=1)
df['startdate'] = pd.to_datetime(df.startdate)
df['Longitude'] = pd.to_numeric(df['Longitude'])
df['Latitude'] = pd.to_numeric(df['Latitude'])
from datetime import timedelta
df['enddate'] = df['startdate'] + timedelta(days=30)
#result['startdate'] = result['startdate'].dt.date
df = df.sort_values(by = ['startdate'])
df.index = range(len(df))
df
# Out:
#        cluster   depth  Latitude  Longitude  mag startday startmonth  \
# 0            5     0.0   57.0900  -153.4800  8.3       10         10
# 1            5     0.0   60.0000  -135.0000  7.1       18          1
# 2            5     0.0   52.0000  -160.0000  6.6       30         12
# 3            5     0.0   51.4500  -171.0200  7.8       31         12
# 4            5     0.0   52.3800  -167.4500  7.8        1          1
# 5            5     0.0   50.8500  -175.1600  7.0       17          1
# 6            5     0.0   52.0000   175.0000  6.8        5          2
# 7            5     0.0   61.5600  -158.5400  8.3        2          6
# 8            5     0.0   64.6200  -148.2300  7.8       27          8
# 9            5     0.0   50.7300  -178.5500  7.7       14          2
# 10           5     0.0   51.2800   174.8300  7.2       22          3
# 11           7     0.0   52.0600   171.4500  7.4       15          9
# 12           5     0.0   53.8800  -161.6800  7.0       10         12
# ...

# %%
df = dff.copy()

# %%
for i in range(0, len(df)-1):
    df2 = df[(df['startdate'] >= df['startdate'][i]) & (df['startdate'] < df['enddate'][i]) & (df['Longitude'] >= df['Longitude'][i] - 1) & (df['Longitude'] < df['Longitude'][i] + 1) & (df['Latitude'] >= df['Latitude'][i] - 1) & (df['Latitude'] < df['Latitude'][i] + 1)]
    if len(df2) >= 100:
        print i
        print len(df2)
        df2['type'][i] = '2'
        df = df[~((df['startdate'] >= df['startdate'][i]) & (df['startdate'] < df['enddate'][i]) & (df['Longitude'] >= df['Longitude'][i] - 1) & (df['Longitude'] < df['Longitude'][i] + 1) & (df['Latitude'] >= df['Latitude'][i] - 1) & (df['Latitude'] < df['Latitude'][i] + 1) & (df['type'] == '1'))]
        df.index = range(len(df))
# Out:
# 240
# 180
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 4454
# 255
# 5152
# 104
# 7261
# 101
# 11074
# 196
# 11162
# 114
# 13095
# 138
# 13096
# 111
# 16929
# 209
# 16930
# 110
# 16931
# 163
# 16940
# 129
# 17476
# 105
# 27124
# 117
# 33066
# 100
# 33258
# 141
# 33784
# 255
# 36001
# 101
# 39562
# 260
# 46454
# 122
# 46882
# 283
# 48874
# 101
# 49096
# 183
# 49268
# 102
# 52265
# 115
# 52752
# 102
# 55720
# 103
# 57299
# 118
# 60404
# 118
# 68587
# 127
# 71514
# 110
# 72235
# 115
# 74148
# 167
# 74573
# 102
# 75338
# 113
# 84520
# 103
# 87628
# 196
# 92739
# 135
# 93201
# 100
# 96941
# 110
# 96973
# 149
# 100100
# 273
# 100575
# 423
# 100831
# 417
# 101246
# 138
# 101773
# 109
# 105649
# 126
# 110882
# 100
# 118197
# 133
# 120091
# 100
# 120093
# ...

# %%
df
# Out:
#        cluster   depth  Latitude  Longitude  mag startday startmonth  \
# 0            5     0.0   57.0900  -153.4800  8.3       10         10
# 1            5     0.0   60.0000  -135.0000  7.1       18          1
# 2            5     0.0   52.0000  -160.0000  6.6       30         12
# 3            5     0.0   51.4500  -171.0200  7.8       31         12
# 4            5     0.0   52.3800  -167.4500  7.8        1          1
# 5            5     0.0   50.8500  -175.1600  7.0       17          1
# 6            5     0.0   52.0000   175.0000  6.8        5          2
# 7            5     0.0   61.5600  -158.5400  8.3        2          6
# 8            5     0.0   64.6200  -148.2300  7.8       27          8
# 9            5     0.0   50.7300  -178.5500  7.7       14          2
# 10           5     0.0   51.2800   174.8300  7.2       22          3
# 11           7     0.0   52.0600   171.4500  7.4       15          9
# 12           5     0.0   53.8800  -161.6800  7.0       10         12
# ...

# %%
df[240:]
# Out:
#        cluster   depth  Latitude  Longitude   mag startday startmonth  \
# 240          0     6.0   35.9650  -117.8030   3.8       26          2
# 241          0     6.0   34.3333  -119.5000  3.32        7          3
# 242          0     6.0   33.5000  -116.7500  3.14        8          3
# 243          0     6.0   33.8400  -118.2080  4.25       30          3
# 244          0     6.0   33.8220  -118.2260  3.86       31          3
# 245          0     6.0   33.5520  -118.0410  4.21        1          4
# 246          0     6.0   33.4240  -118.1560  3.39        2          4
# 247          0     6.0   33.7500  -118.0833  3.66        2          4
# 248          0     6.0   33.5830  -117.9620   3.2        2          4
# 249          0     6.0   33.3500  -118.1780  3.75        2          4
# 250          0     6.0   33.4860  -117.6170  3.26        3          4
# 251          0     6.0   33.9770  -116.5330  3.62        4          4
# ...
