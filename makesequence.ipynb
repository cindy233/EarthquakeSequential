# %%
import numpy as np
import pandas as pd
from datetime import datetime
import ephem

def get_phase_on_day(date):
    d = ephem.Date(date)
    pnm = ephem.previous_new_moon(date)
    lunation = int(d - pnm)
    return lunation

df1 = pd.read_csv('basket.csv', dtype = object)
df1
# Out:
#     cluster   startdate type
# 0         6  2001-01-01    E
# 1         6  2001-01-01    E
# 2         6  2001-01-02    E
# 3        11  2001-01-02    E
# 4         8  2001-01-08    V
# 5        11  2001-01-09    E
# 6         5  2001-01-10    E
# 7         6  2001-01-11    V
# 8         7  2001-01-11    V
# 9         5  2001-01-11    E
# 10       14  2001-01-13    E
# 11        2  2001-01-15    E
# 12       10  2001-01-16    E
# 13       10  2001-01-16    E
# 14       11  2001-01-16    V
# 15       14  2001-01-17    V
# 16        0  2001-01-19    E
# 17       11  2001-01-19    E
# 18        3  2001-01-19    E
# 19       13  2001-01-26    E
# 20        6  2001-01-29    E
# 21        5  2001-02-01    E
# 22        5  2001-02-02    V
# 23        9  2001-02-06    V
# 24       10  2001-02-13    E
# 25       14  2001-02-13    E
# 26       11  2001-02-14    E
# 27       11  2001-02-14    E
# 28        6  2001-02-16    E
# 29        5  2001-02-17    E
# ..      ...         ...  ...
# ...

# %%
df1['startdate'] = pd.to_datetime(df1.startdate)
df1['startdate'] = df1['startdate'].dt.date
df1['phase'] = ' '
type(df1['startdate'][0])
for i in range(0, len(df1)):
    df1['phase'][i] = get_phase_on_day(df1['startdate'][i])

# %%
df1
# Out:
#     cluster   startdate type phase
# 0         6  2001-01-01    E     6
# 1         6  2001-01-01    E     6
# 2         6  2001-01-02    E     7
# 3        11  2001-01-02    E     7
# 4         8  2001-01-08    V    13
# 5        11  2001-01-09    E    14
# 6         5  2001-01-10    E    15
# 7         6  2001-01-11    V    16
# 8         7  2001-01-11    V    16
# 9         5  2001-01-11    E    16
# 10       14  2001-01-13    E    18
# 11        2  2001-01-15    E    20
# 12       10  2001-01-16    E    21
# 13       10  2001-01-16    E    21
# 14       11  2001-01-16    V    21
# 15       14  2001-01-17    V    22
# 16        0  2001-01-19    E    24
# 17       11  2001-01-19    E    24
# 18        3  2001-01-19    E    24
# 19       13  2001-01-26    E     1
# 20        6  2001-01-29    E     4
# 21        5  2001-02-01    E     7
# 22        5  2001-02-02    V     8
# 23        9  2001-02-06    V    12
# 24       10  2001-02-13    E    19
# 25       14  2001-02-13    E    19
# ...

# %%
df1['sequence']=df1['type'] + df1['cluster'].map(str)

# %%
df1
# Out:
#     cluster   startdate type phase sequence
# 0         6  2001-01-01    E     6       E6
# 1         6  2001-01-01    E     6       E6
# 2         6  2001-01-02    E     7       E6
# 3        11  2001-01-02    E     7      E11
# 4         8  2001-01-08    V    13       V8
# 5        11  2001-01-09    E    14      E11
# 6         5  2001-01-10    E    15       E5
# 7         6  2001-01-11    V    16       V6
# 8         7  2001-01-11    V    16       V7
# 9         5  2001-01-11    E    16       E5
# 10       14  2001-01-13    E    18      E14
# 11        2  2001-01-15    E    20       E2
# 12       10  2001-01-16    E    21      E10
# 13       10  2001-01-16    E    21      E10
# 14       11  2001-01-16    V    21      V11
# 15       14  2001-01-17    V    22      V14
# 16        0  2001-01-19    E    24       E0
# 17       11  2001-01-19    E    24      E11
# 18        3  2001-01-19    E    24       E3
# 19       13  2001-01-26    E     1      E13
# ...

# %%
with open("test.txt", "a") as myfile:
        myfile.write(df1['sequence'][0])
for x in range(1, len(df1['sequence'])):
    #if date and sequence are different from the previous one
    if ((df1['startdate'][x] != df1['startdate'][x - 1]) and (df1['sequence'][x] != df1['sequence'][x - 1])):
        with open("test.txt", "a") as myfile:
            myfile.write(' ' + str(df1['phase'][x-1]) +' -1 ' + df1['sequence'][x] )
    #if date is the same but sequence is different
    elif df1['sequence'][x] != df1['sequence'][x - 1]:
        with open("test.txt", "a") as myfile:
            myfile.write(' ' + df1['sequence'][x])
with open("test.txt", "a") as myfile:
        myfile.write(' ' + str(df1['phase'][len(df1['phase']) - 1]) + ' -1 -2\n')
