# %%
import numpy as np
import pandas as pd
file = open('catsearch1.csv', 'r')
mags = []
datetimes = []
years = []
months = []
days = []
clus = []
types = []

firstline = True
for line in file:
    if firstline:    #skip first line
        firstline = False
        continue
    data = line.strip().split(',')
    datetime = str(data[0])
    datetimes.append(datetime)
    year = str(data[0])[:4]
    years.append(year)
    month = str(data[0])[5:7]
    months.append(month)
    day = str(data[0])[8:10]
    days.append(day)
    mag = float(data[1])
    mags.append(mag)
    clu = int(data[4])
    clus.append(clu)
    typ = str('E')
    types.append(typ)
    
mags = np.asarray(mags)
datetimes = np.asarray(datetimes)
years = np.asarray(years)
months = np.asarray(months)
days = np.asarray(days)
clus = np.asarray(clus)
types = np.asarray(types)

# %%
all_data = {'year': years, 'month': months, 'day': days, 'mag': mags, 'cluster': clus, 'type': types}

# %%
df = pd.DataFrame(all_data)
df
# Out:
#         cluster day  mag month type  year
# 0             9  29  7.6    06    E  1898
# 1             4  11  6.9    10    E  1898
# 2             4  14  7.2    07    E  1899
# 3             4  04  8.3    09    E  1899
# 4             4  04  6.9    09    E  1899
# 5             4  10  7.8    09    E  1899
# 6             4  10  8.6    09    E  1899
# 7             4  17  6.9    09    E  1899
# 8             4  23  6.9    09    E  1899
# 9             4  23  7.0    09    E  1899
# 10            4  29  6.8    09    E  1899
# 11            4  10  8.3    10    E  1900
# 12            4  18  7.1    01    E  1901
# 13            4  30  6.6    12    E  1901
# 14            4  31  7.8    12    E  1901
# 15            4  01  7.8    01    E  1902
# 16            4  17  7.0    01    E  1903
# 17            9  05  6.8    02    E  1903
# 18            4  02  8.3    06    E  1903
# 19            4  27  7.8    08    E  1904
# 20            4  14  7.7    02    E  1905
# 21            9  22  7.2    03    E  1905
# 22            9  15  7.4    09    E  1905
# 23            4  10  7.0    12    E  1905
# 24            9  17  8.0    08    E  1906
# 25            4  23  7.6    12    E  1906
# 26            4  22  6.5    08    E  1907
# 27            9  02  7.7    09    E  1907
# 28            4  15  7.1    05    E  1908
# 29            9  10  7.0    04    E  1909
# ...         ...  ..  ...   ...  ...   ...
# 617840        5  04  4.6    07    E  2016
# 617841        7  04  4.9    07    E  2016
# 617842        3  04  4.2    07    E  2016
# 617843        9  04  4.6    07    E  2016
# 617844        0  04  4.4    07    E  2016
# 617845        6  04  4.7    07    E  2016
# 617846        2  04  4.3    07    E  2016
# 617847        9  04  4.4    07    E  2016
# 617848        6  05  5.0    07    E  2016
# 617849        2  05  3.0    07    E  2016
# 617850        3  05  4.4    07    E  2016
# 617851        0  05  4.5    07    E  2016
# 617852        9  05  4.8    07    E  2016
# 617853        0  05  4.4    07    E  2016
# 617854        1  05  3.1    07    E  2016
# 617855        9  05  5.2    07    E  2016
# 617856        3  05  4.3    07    E  2016
# 617857        1  05  3.5    07    E  2016
# 617858        6  05  4.3    07    E  2016
# 617859        5  05  5.2    07    E  2016
# 617860        0  05  4.3    07    E  2016
# 617861        1  05  3.5    07    E  2016
# 617862        3  05  4.4    07    E  2016
# 617863        9  05  4.6    07    E  2016
# 617864        1  05  4.3    07    E  2016
# 617865        9  05  4.4    07    E  2016
# 617866        7  06  4.8    07    E  2016
# 617867        5  06  5.9    07    E  2016
# 617868        4  06  3.8    07    E  2016
# 617869        2  06  4.3    07    E  2016
#
# [617870 rows x 6 columns]

# %%
df2 = df.query('year == "2001" and mag >= 6')

# %%
df2
# Out:
#         cluster day   mag month type  year
# 325668        0  01  7.50    01    E  2001
# 325672        0  01  6.80    01    E  2001
# 325705        0  02  6.40    01    E  2001
# 325724        7  02  6.00    01    E  2001
# 325955        7  09  7.10    01    E  2001
# 326005        4  10  6.93    01    E  2001
# 326023        1  11  6.00    01    E  2001
# 326096        2  13  7.70    01    E  2001
# 326177        0  15  6.40    01    E  2001
# 326229        0  16  6.00    01    E  2001
# 326230        0  16  6.90    01    E  2001
# 326340        2  19  6.00    01    E  2001
# 326349        7  19  6.30    01    E  2001
# 326352        6  19  6.00    01    E  2001
# 326640        3  26  7.70    01    E  2001
# 326795        0  29  6.20    01    E  2001
# 326926        4  01  6.00    02    E  2001
# 327425        2  13  6.60    02    E  2001
# 327441        0  13  7.40    02    E  2001
# 327476        7  14  6.10    02    E  2001
# 327478        7  14  6.20    02    E  2001
# 327526        0  16  6.10    02    E  2001
# 327596        1  17  6.20    02    E  2001
# 327641        3  18  6.00    02    E  2001
# 327862        0  24  7.10    02    E  2001
# 327875        0  24  6.20    02    E  2001
# 327907        3  25  6.20    02    E  2001
# 327972        9  26  6.10    02    E  2001
# 328081        7  28  6.70    02    E  2001
# 328083        7  28  6.30    02    E  2001
# ...         ...  ..   ...   ...  ...   ...
# 337982        2  17  6.00    10    E  2001
# 338061        0  19  7.50    10    E  2001
# 338141        7  21  6.70    10    E  2001
# 338406        7  26  6.10    10    E  2001
# 338605        7  31  7.00    10    E  2001
# 338855        5  05  6.30    11    E  2001
# 338995        2  09  6.10    11    E  2001
# 339204        1  13  6.10    11    E  2001
# 339209        9  13  6.00    11    E  2001
# 339210        9  13  6.00    11    E  2001
# 339260        3  14  7.80    11    E  2001
# 339302        8  15  6.30    11    E  2001
# 339543        0  20  6.20    11    E  2001
# 339609        7  22  6.30    11    E  2001
# 339610        7  22  6.20    11    E  2001
# 339650        3  23  6.10    11    E  2001
# 339782        5  27  6.00    11    E  2001
# 339853        2  28  6.40    11    E  2001
# 340038        7  02  6.00    12    E  2001
# 340056        9  02  6.50    12    E  2001
# 340094        5  03  6.40    12    E  2001
# 340368        9  08  6.20    12    E  2001
# 340430        0  09  6.10    12    E  2001
# 340533        7  12  6.10    12    E  2001
# 340535        7  12  7.10    12    E  2001
# 340777        0  18  6.80    12    E  2001
# 340961        7  22  6.00    12    E  2001
# 341034        7  23  6.80    12    E  2001
# 341190        7  27  6.20    12    E  2001
# 341252        2  28  6.00    12    E  2001
#
# [138 rows x 6 columns]

# %%
df2.to_csv('2001magbigger6.csv')
